# %%
from google.colab import drive
import pandas as pd
import numpy as np
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = "/content/drive/My Drive/BA820 Project/Dataset/merged_data_small.csv"
reviews = pd.read_csv(file_path)

# %%
reviews.to_parquet("merged_data_small.parquet", index=False)

# %%
from google.colab import files
files.download("merged_data_small.parquet")
